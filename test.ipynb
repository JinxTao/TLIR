# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as psnr
r = 'sr_ffhq_230406_203722'
result = 119
epoch = 30
# imghr = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/0_1_hr.npy'.format(r,result,epoch))
# imgsr = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/0_1_sr.npy'.format(r,result,epoch))
# imghr2 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/0_2_hr.npy'.format(r,result,epoch))
# imgsr2 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/0_2_sr.npy'.format(r,result,epoch))
# imghr3 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/0_3_hr.npy'.format(r,result,epoch))
# imgsr3 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/0_3_sr.npy'.format(r,result,epoch))

imghr = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/{}/{}0000_1_hr.npy'.format(r,result,epoch))
imgsr = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/{}/{}0000_1_sr.npy'.format(r,result,epoch))
imghr2 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/{}/{}0000_2_hr.npy'.format(r,result,epoch))
imgsr2 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/{}/{}0000_2_sr.npy'.format(r,result,epoch))
imghr3 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/{}/{}0000_3_hr.npy'.format(r,result,epoch))
imgsr3 = np.load('/media/ext_disk/wangtao/save/experiments/{}/results/{}/{}0000_3_sr.npy'.format(r,result,epoch))
plt.figure()
plt.subplot(1,3,1)
plt.imshow(imghr[0], cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(imgsr[0], cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(imghr[0]-imgsr[0], cmap = 'gray')
plt.figure()
plt.subplot(1,3,1)
plt.imshow(imghr2[0], cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(imgsr2[0], cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(imghr2[0]-imgsr2[0], cmap = 'gray')
plt.figure()
plt.subplot(1,3,1)
plt.imshow(imghr3[0], cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(imgsr3[0], cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(imghr3[0]-imgsr3[0], cmap = 'gray')
from skimage.metrics import structural_similarity as ssim
print(ssim(imghr[0],imgsr[0], data_range=imghr.max() - imghr.min()))
print(psnr(imghr,imgsr, data_range=imghr.max() - imghr.min()))
print(ssim(imghr2[0],imgsr2[0], data_range=imghr.max() - imghr.min()))
print(psnr(imghr2,imgsr2, data_range=imghr.max() - imghr.min()))
print(ssim(imghr3[0],imgsr3[0], data_range=imghr.max() - imghr.min()))
print(psnr(imghr3,imgsr3, data_range=imghr.max() - imghr.min()))
imgsr = imgsr.squeeze(0)
imghr = imghr.squeeze(0)
imgsr2 = imgsr2.squeeze(0)
imghr2 = imghr2.squeeze(0)
imgsr3 = imgsr3.squeeze(0)
imghr3 = imghr3.squeeze(0)
# Out:
# 0.8049026051502367
# 30.986384217139218
# 0.9245305054824352
# 37.65832660600269
# 0.8521731306175963
# 30.929659532069028
